# %% [markdown]
# #### Data processing

# %%
import pandas as pd

input = pd.read_csv('Brain_eid_GMV.csv')
covariate = pd.read_csv('age_sex_head_brain.csv')
count = pd.read_csv('score_counts_brain.csv')

data = pd.merge(input, covariate, on='eid')
data = pd.merge(data, count, on='eid')

data3 = data[data['D_count'] == 0]
data = data[data['D_count'] != 0]
data1 = data[(data['D_count'] >= 2)]
data2 = data[(data['D_count'] <  2)]

print("all:", data.shape[0])
print("Health:", data3.shape[0])
print("Co:", data1.shape[0])
print("Single:", data2.shape[0])

data1.to_csv('GMV_Co.csv',index=False)
data2.to_csv('GMV_Single.csv',index=False)
data3.to_csv('GMV_HC.csv',index=False)
# Out:
# all: 11042
# Health: 24014
# Co: 4038
# Single: 7004

# %% [markdown]
# #### Oneway ANOVA (analysis of variance)

# %%
import pandas as pd
from scipy.stats import f_oneway

data_1 = pd.read_csv('GMV_Co.csv')
data_2 = pd.read_csv('GMV_Single.csv')
data_3 = pd.read_csv('GMV_HC.csv')

data1 = data_1.iloc[:, 1:-9]
data2 = data_2.iloc[:, 1:-9]
data3 = data_3.iloc[:, 1:-9]

labels = pd.read_csv('D:/python_code/cluster/Updated_GMV.csv')

new_columns = labels['Description'].tolist()

data1.columns = new_columns
data2.columns = new_columns
data3.columns = new_columns

"""data1 = data1.iloc[:, 111:]
data2 = data2.iloc[:, 111:]
data3 = data3.iloc[:, 111:]"""

labels = data1.columns

alpha = 0.05
significant_columns = []
f_statistic_list = []
f_scores_df = pd.DataFrame(columns=['col_name', 'f_statistic', 'p_value'])

for col_name in labels:
    f_statistic, p_value = f_oneway(data1[col_name], data2[col_name], data3[col_name])
    f_statistic_list.append((f_statistic, col_name))

    f_scores_df.loc[len(f_scores_df)] = [col_name, f_statistic, p_value]

    alpha_adjusted = alpha / len(new_columns)

    if p_value < alpha_adjusted:
        #print("At a significance level of", alpha_adjusted, "There are significant differences in the means of at least one set of data. \n")
        significant_columns.append(col_name)
    else:
        print("Column:", col_name)
        print("At a significance level of", alpha_adjusted, "There was no significant difference in the mean values of the data in each group. \n")

sorted_f_statistic_list = sorted(f_statistic_list, key=lambda x: x[0], reverse=True)
sorted_column_names = [col_name for f_statistic, col_name in sorted_f_statistic_list]
#ten_list = sorted_column_names[:11]
#f_scores_df.to_csv('GMV f score.csv', index=False)
#print(ten_list)
print(len(significant_columns))
# Out:
# Column: Middle Temporal Gyrus, temporooccipital part (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Inferior Temporal Gyrus, posterior division (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Inferior Temporal Gyrus, temporooccipital part (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Inferior Temporal Gyrus, temporooccipital part (right)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Angular Gyrus (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Intracalcarine Cortex (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Subcallosal Cortex (right)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Cingulate Gyrus, anterior division (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Cingulate Gyrus, anterior division (right)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Cingulate Gyrus, posterior division (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Cingulate Gyrus, posterior division (right)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Planum Temporale (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Supracalcarine Cortex (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Supracalcarine Cortex (right)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Thalamus (left)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# Column: Crus I Cerebellum (vermis)
# At a significance level of 0.00035971223021582735 There was no significant difference in the mean values of the data in each group.
#
# 123

# %% [markdown]
# #### Two-sample t-test with covariates

# %%
import numpy as np
import pandas as pd
from scipy.stats import f
from statsmodels.stats.multitest import multipletests

def y_regress_ss(Y, X):
    coefficients = np.linalg.lstsq(X, Y, rcond=None)[0]

    predicted = np.dot(X, coefficients)

    residuals = Y - predicted

    SSE = np.sum(residuals**2)

    return coefficients, residuals, SSE

def y_TTest2Cov(Variable1, Variable2, CovariateVariable1=None, CovariateVariable2=None):
    if CovariateVariable1 is None:
        CovariateVariable1 = np.array([])
    if CovariateVariable2 is None:
        CovariateVariable2 = np.array([])

    DependentVariable = np.concatenate((Variable1, Variable2))
    CovariateVariable = np.vstack((CovariateVariable1, CovariateVariable2))
    GroupLabel = np.concatenate((np.ones(len(Variable1)), -1 * np.ones(len(Variable2))))
    Df_E = DependentVariable.shape[0] - 2 - CovariateVariable.shape[1]

    b, r, SSE_H = y_regress_ss(DependentVariable, np.column_stack((np.ones(len(DependentVariable)), CovariateVariable)))

    b, r, SSE = y_regress_ss(DependentVariable, np.column_stack((np.ones(len(DependentVariable)), GroupLabel, CovariateVariable)))

    F = ((SSE_H - SSE) / 1) / (SSE / Df_E)
    P = 1 - f.cdf(F, 1, Df_E)
    T = np.sqrt(F) * np.sign(b[1])

    return T, P

# %%
def perform_t_test(data1, data2, covariate1, covariate2, i):
    significant_columns = []
    result_df = pd.DataFrame(columns=['i', 'col_name', 'TTest2Cov_T', 'TTest2Cov_P'])

    for col_name in data1.columns:
        col_data1 = np.array(data1[col_name])
        col_data2 = np.array(data2[col_name])
        covariate1_array = np.array(covariate1)
        covariate2_array = np.array(covariate2)
        
        TTest2Cov_T, TTest2Cov_P = y_TTest2Cov(col_data1, col_data2, covariate1_array, covariate2_array)

        alpha = 0.05
        p_values = [TTest2Cov_P]

        corrected_p_values = multipletests(p_values, alpha=alpha, method='sidak')[1]

        result_df = pd.concat([result_df, pd.DataFrame({'i': [i], 'col_name': [col_name], 'TTest2Cov_T': [TTest2Cov_T], 'TTest2Cov_P': [TTest2Cov_P]})], ignore_index=True)

        if corrected_p_values[0] < alpha:
            print(f"{i} in {col_name} are significant differences")
            print(f"{i} in {col_name} T values is:{TTest2Cov_T}")
            print(f"{i} in {col_name} p values is:{TTest2Cov_P}")
            #result_df = pd.concat([result_df, pd.DataFrame({'i': [i], 'col_name': [col_name], 'TTest2Cov_T': [TTest2Cov_T], 'TTest2Cov_P': [TTest2Cov_P]})], ignore_index=True)
            significant_columns.append(col_name)

    result_df.to_csv(f'{i}_result.csv', index=False)

    result_df['TTest2Cov_T'] = result_df['TTest2Cov_T'].abs()
    
    result_df = result_df.sort_values(by='TTest2Cov_T', ascending=False)

    top_10_col_names = result_df['col_name'].head(10).tolist()

    return significant_columns, top_10_col_names

# %% [markdown]
# #### D factor T test

# %%
data_1 = pd.read_csv('GMV_Co.csv')
data_2 = pd.read_csv('GMV_Single.csv')
data_3 = pd.read_csv('GMV_HC.csv')

data1 = data_1.iloc[:, 1:-9]
data2 = data_2.iloc[:, 1:-9]
data3 = data_3.iloc[:, 1:-9]

labels = pd.read_csv('D:/python_code/cluster/Updated_GMV.csv')

new_columns = labels['Description'].tolist()

data1.columns = new_columns
data2.columns = new_columns
data3.columns = new_columns

covariate1 = data_1[['age','sex']]
covariate2 = data_2[['age','sex']]
covariate3 = data_3[['age','sex']]

significant_columns_1_2, top_10_1_2 = perform_t_test(data1, data2, covariate1, covariate2, 'Co_Single')
significant_columns_1_3, top_10_1_3 = perform_t_test(data1, data3, covariate1, covariate3, 'Co_HC')
significant_columns_2_3, top_10_2_3 = perform_t_test(data2, data3, covariate2, covariate3, 'Single_HC')
# Out:
# Co_Single in Frontal Pole (left) are significant differences
# Co_Single in Frontal Pole (left) T values is:-3.6937521271808116
# Co_Single in Frontal Pole (left) p values is:0.00022203603700488017
# Co_Single in Frontal Pole (right) are significant differences
# Co_Single in Frontal Pole (right) T values is:-3.676097125617666
# Co_Single in Frontal Pole (right) p values is:0.00023795238170531974
# Co_Single in Insular Cortex (left) are significant differences
# Co_Single in Insular Cortex (left) T values is:-4.2240094900849305
# Co_Single in Insular Cortex (left) p values is:2.4192026869651606e-05
# Co_Single in Insular Cortex (right) are significant differences
# Co_Single in Insular Cortex (right) T values is:-4.132368407378926
# Co_Single in Insular Cortex (right) p values is:3.6169499977312114e-05
# Co_Single in Precentral Gyrus (left) are significant differences
# Co_Single in Precentral Gyrus (left) T values is:-2.1364800399239496
# Co_Single in Precentral Gyrus (left) p values is:0.03266223288983949
# Co_Single in Precentral Gyrus (right) are significant differences
# Co_Single in Precentral Gyrus (right) T values is:-3.8816235025654398
# Co_Single in Precentral Gyrus (right) p values is:0.00010436546123138157
# Co_Single in Temporal Pole (left) are significant differences
# Co_Single in Temporal Pole (left) T values is:-3.837948542794588
# Co_Single in Temporal Pole (left) p values is:0.00012475846199067053
# Co_Single in Temporal Pole (right) are significant differences
# Co_Single in Temporal Pole (right) T values is:-4.370173277944969
# Co_Single in Temporal Pole (right) p values is:1.2528291395086377e-05
# Co_Single in Superior Temporal Gyrus, anterior division (left) are significant differences
# Co_Single in Superior Temporal Gyrus, anterior division (left) T values is:-3.121802546457062
# Co_Single in Superior Temporal Gyrus, anterior division (left) p values is:0.001802116458933023
# Co_Single in Superior Temporal Gyrus, anterior division (right) are significant differences
# Co_Single in Superior Temporal Gyrus, anterior division (right) T values is:-3.60375590169877
# Co_Single in Superior Temporal Gyrus, anterior division (right) p values is:0.00031503199687266115
# Co_Single in Superior Temporal Gyrus, posterior division (left) are significant differences
# Co_Single in Superior Temporal Gyrus, posterior division (left) T values is:-2.292468332088439
# Co_Single in Superior Temporal Gyrus, posterior division (left) p values is:0.021897357241631554
# Co_Single in Superior Temporal Gyrus, posterior division (right) are significant differences
# Co_Single in Superior Temporal Gyrus, posterior division (right) T values is:-3.5107416950345303
# Co_Single in Superior Temporal Gyrus, posterior division (right) p values is:0.0004486416248203895
# Co_Single in Middle Temporal Gyrus, anterior division (left) are significant differences
# Co_Single in Middle Temporal Gyrus, anterior division (left) T values is:-4.202048311610659
# Co_Single in Middle Temporal Gyrus, anterior division (left) p values is:2.6659196032285948e-05
# Co_Single in Middle Temporal Gyrus, anterior division (right) are significant differences
# Co_Single in Middle Temporal Gyrus, anterior division (right) T values is:-2.2184731355491425
# Co_Single in Middle Temporal Gyrus, anterior division (right) p values is:0.026542857382459317
# Co_Single in Middle Temporal Gyrus, posterior division (left) are significant differences
# Co_Single in Middle Temporal Gyrus, posterior division (left) T values is:-2.9142940493965117
# Co_Single in Middle Temporal Gyrus, posterior division (left) p values is:0.003572099198632661
# Co_Single in Middle Temporal Gyrus, posterior division (right) are significant differences
# Co_Single in Middle Temporal Gyrus, posterior division (right) T values is:-2.741192773536665
# Co_Single in Middle Temporal Gyrus, posterior division (right) p values is:0.006131510726204548
# Co_Single in Middle Temporal Gyrus, temporooccipital part (right) are significant differences
# Co_Single in Middle Temporal Gyrus, temporooccipital part (right) T values is:-3.19137026500778
# Co_Single in Middle Temporal Gyrus, temporooccipital part (right) p values is:0.0014199627232398537
# Co_Single in Inferior Temporal Gyrus, anterior division (left) are significant differences
# Co_Single in Inferior Temporal Gyrus, anterior division (left) T values is:-2.334030557728104
# Co_Single in Inferior Temporal Gyrus, anterior division (left) p values is:0.019611970787550614
# Co_Single in Inferior Temporal Gyrus, anterior division (right) are significant differences
# Co_Single in Inferior Temporal Gyrus, anterior division (right) T values is:-2.3601289337415983
# Co_Single in Inferior Temporal Gyrus, anterior division (right) p values is:0.018285883248920443
# Co_Single in Postcentral Gyrus (left) are significant differences
# Co_Single in Postcentral Gyrus (left) T values is:-2.5678937203788235
# Co_Single in Postcentral Gyrus (left) p values is:0.01024489181856647
# Co_Single in Postcentral Gyrus (right) are significant differences
# Co_Single in Postcentral Gyrus (right) T values is:-4.285961964874024
# Co_Single in Postcentral Gyrus (right) p values is:1.834940987099909e-05
# Co_Single in Supramarginal Gyrus, anterior division (right) are significant differences
# Co_Single in Supramarginal Gyrus, anterior division (right) T values is:-2.9805178463988806
# Co_Single in Supramarginal Gyrus, anterior division (right) p values is:0.0028838868495528747
# Co_Single in Supramarginal Gyrus, posterior division (left) are significant differences
# Co_Single in Supramarginal Gyrus, posterior division (left) T values is:-2.2392928583654133
# Co_Single in Supramarginal Gyrus, posterior division (left) p values is:0.02515670409790549
# Co_Single in Angular Gyrus (left) are significant differences
# Co_Single in Angular Gyrus (left) T values is:-2.749238634204525
# Co_Single in Angular Gyrus (left) p values is:0.005983104021511809
# Co_Single in Lateral Occipital Cortex, superior division (left) are significant differences
# Co_Single in Lateral Occipital Cortex, superior division (left) T values is:-2.8370623455849606
# Co_Single in Lateral Occipital Cortex, superior division (left) p values is:0.004561367627143986
# Co_Single in Lateral Occipital Cortex, superior division (right) are significant differences
# Co_Single in Lateral Occipital Cortex, superior division (right) T values is:-2.0441088328790613
# Co_Single in Lateral Occipital Cortex, superior division (right) p values is:0.040966477028977044
# Co_Single in Lateral Occipital Cortex, inferior division (left) are significant differences
# Co_Single in Lateral Occipital Cortex, inferior division (left) T values is:-2.087930013622097
# Co_Single in Lateral Occipital Cortex, inferior division (left) p values is:0.036827015396035945
# Co_Single in Intracalcarine Cortex (right) are significant differences
# Co_Single in Intracalcarine Cortex (right) T values is:-2.24701015034958
# Co_Single in Intracalcarine Cortex (right) p values is:0.024659054680206127
# Co_Single in Frontal Medial Cortex (left) are significant differences
# Co_Single in Frontal Medial Cortex (left) T values is:-3.870820435056806
# Co_Single in Frontal Medial Cortex (left) p values is:0.0001090944877712996
# Co_Single in Frontal Medial Cortex (right) are significant differences
# Co_Single in Frontal Medial Cortex (right) T values is:-3.8316989316705263
# Co_Single in Frontal Medial Cortex (right) p values is:0.00012796686822369452
# Co_Single in Juxtapositional Lobule Cortex (left) are significant differences
# Co_Single in Juxtapositional Lobule Cortex (left) T values is:-2.1677057191821527
# Co_Single in Juxtapositional Lobule Cortex (left) p values is:0.030202387927263374
# Co_Single in Subcallosal Cortex (left) are significant differences
# Co_Single in Subcallosal Cortex (left) T values is:-2.2505497156304948
# Co_Single in Subcallosal Cortex (left) p values is:0.024433673808845424
# Co_Single in Paracingulate Gyrus (left) are significant differences
# Co_Single in Paracingulate Gyrus (left) T values is:-2.5268874357092446
# Co_Single in Paracingulate Gyrus (left) p values is:0.011521690173066812
# Co_Single in Paracingulate Gyrus (right) are significant differences
# Co_Single in Paracingulate Gyrus (right) T values is:-2.5345037813899967
# Co_Single in Paracingulate Gyrus (right) p values is:0.011274371053270449
# Co_Single in Precuneous Cortex (left) are significant differences
# Co_Single in Precuneous Cortex (left) T values is:-3.6036574001297885
# Co_Single in Precuneous Cortex (left) p values is:0.00031515132676762647
# Co_Single in Precuneous Cortex (right) are significant differences
# Co_Single in Precuneous Cortex (right) T values is:-3.0168146116093824
# Co_Single in Precuneous Cortex (right) p values is:0.0025602792896055604
# Co_Single in Cuneal Cortex (left) are significant differences
# Co_Single in Cuneal Cortex (left) T values is:-2.210428215836898
# Co_Single in Cuneal Cortex (left) p values is:0.027095891172389197
# Co_Single in Frontal Orbital Cortex (left) are significant differences
# Co_Single in Frontal Orbital Cortex (left) T values is:-3.208739128838695
# Co_Single in Frontal Orbital Cortex (left) p values is:0.0013369933665901002
# Co_Single in Frontal Orbital Cortex (right) are significant differences
# Co_Single in Frontal Orbital Cortex (right) T values is:-3.0355080872003275
# Co_Single in Frontal Orbital Cortex (right) p values is:0.002406903369764013
# Co_Single in Parahippocampal Gyrus, anterior division (left) are significant differences
# Co_Single in Parahippocampal Gyrus, anterior division (left) T values is:-3.9109242024294932
# Co_Single in Parahippocampal Gyrus, anterior division (left) p values is:9.249430726998575e-05
# Co_Single in Parahippocampal Gyrus, anterior division (right) are significant differences
# Co_Single in Parahippocampal Gyrus, anterior division (right) T values is:-4.138845791501807
# Co_Single in Parahippocampal Gyrus, anterior division (right) p values is:3.516498241318278e-05
# Co_Single in Parahippocampal Gyrus, posterior division (right) are significant differences
# Co_Single in Parahippocampal Gyrus, posterior division (right) T values is:-2.1677377091380214
# Co_Single in Parahippocampal Gyrus, posterior division (right) p values is:0.03019995185646651
# Co_Single in Lingual Gyrus (left) are significant differences
# Co_Single in Lingual Gyrus (left) T values is:-4.5194425243836305
# Co_Single in Lingual Gyrus (left) p values is:6.264746348794148e-06
# Co_Single in Lingual Gyrus (right) are significant differences
# Co_Single in Lingual Gyrus (right) T values is:-4.8249555033363825
# Co_Single in Lingual Gyrus (right) p values is:1.4190864234819855e-06
# Co_Single in Temporal Fusiform Cortex, anterior division (left) are significant differences
# Co_Single in Temporal Fusiform Cortex, anterior division (left) T values is:-6.103036597313112
# Co_Single in Temporal Fusiform Cortex, anterior division (left) p values is:1.0756552315527301e-09
# Co_Single in Temporal Fusiform Cortex, anterior division (right) are significant differences
# Co_Single in Temporal Fusiform Cortex, anterior division (right) T values is:-5.544163670501773
# Co_Single in Temporal Fusiform Cortex, anterior division (right) p values is:3.0215349888784715e-08
# Co_Single in Temporal Fusiform Cortex, posterior division (left) are significant differences
# Co_Single in Temporal Fusiform Cortex, posterior division (left) T values is:-2.479916075005202
# Co_Single in Temporal Fusiform Cortex, posterior division (left) p values is:0.013156134678597553
# Co_Single in Temporal Fusiform Cortex, posterior division (right) are significant differences
# Co_Single in Temporal Fusiform Cortex, posterior division (right) T values is:-3.873481262101662
# Co_Single in Temporal Fusiform Cortex, posterior division (right) p values is:0.0001079112972521834
# Co_Single in Temporal Occipital Fusiform Cortex (right) are significant differences
# Co_Single in Temporal Occipital Fusiform Cortex (right) T values is:-3.1685732357578007
# Co_Single in Temporal Occipital Fusiform Cortex (right) p values is:0.0015360700621556145
# Co_Single in Occipital Fusiform Gyrus (right) are significant differences
# Co_Single in Occipital Fusiform Gyrus (right) T values is:-2.7938076527433715
# Co_Single in Occipital Fusiform Gyrus (right) p values is:0.005218123664812779
# Co_Single in Frontal Operculum Cortex (right) are significant differences
# Co_Single in Frontal Operculum Cortex (right) T values is:-2.0890765317251647
# Co_Single in Frontal Operculum Cortex (right) p values is:0.036723679855299785
# Co_Single in Central Opercular Cortex (left) are significant differences
# Co_Single in Central Opercular Cortex (left) T values is:-3.0399979080990773
# Co_Single in Central Opercular Cortex (left) p values is:0.002371340606218464
# Co_Single in Central Opercular Cortex (right) are significant differences
# Co_Single in Central Opercular Cortex (right) T values is:-5.186070065347543
# Co_Single in Central Opercular Cortex (right) p values is:2.1858201937341448e-07
# Co_Single in Parietal Operculum Cortex (left) are significant differences
# Co_Single in Parietal Operculum Cortex (left) T values is:-3.0614626342235733
# Co_Single in Parietal Operculum Cortex (left) p values is:0.002207879807170632
# Co_Single in Parietal Operculum Cortex (right) are significant differences
# Co_Single in Parietal Operculum Cortex (right) T values is:-2.572971967424674
# Co_Single in Parietal Operculum Cortex (right) p values is:0.010095877849305102
# Co_Single in Planum Polare (left) are significant differences
# Co_Single in Planum Polare (left) T values is:-4.833824304165763
# Co_Single in Planum Polare (left) p values is:1.3574006625383106e-06
# Co_Single in Planum Polare (right) are significant differences
# Co_Single in Planum Polare (right) T values is:-5.483927279010046
# Co_Single in Planum Polare (right) p values is:4.2514943121574333e-08
# Co_Single in Heschl's Gyrus (includes H1 and H2) (left) are significant differences
# Co_Single in Heschl's Gyrus (includes H1 and H2) (left) T values is:-3.5348515098465243
# Co_Single in Heschl's Gyrus (includes H1 and H2) (left) p values is:0.000409674752202549
# Co_Single in Heschl's Gyrus (includes H1 and H2) (right) are significant differences
# Co_Single in Heschl's Gyrus (includes H1 and H2) (right) T values is:-5.164411115980345
# Co_Single in Heschl's Gyrus (includes H1 and H2) (right) p values is:2.4539988441318883e-07
# Co_Single in Planum Temporale (right) are significant differences
# Co_Single in Planum Temporale (right) T values is:-3.4209219107480937
# Co_Single in Planum Temporale (right) p values is:0.000626353526810286
# Co_Single in Putamen (left) are significant differences
# Co_Single in Putamen (left) T values is:-2.648966768237587
# Co_Single in Putamen (left) p values is:0.008085321407031332
# Co_Single in Putamen (right) are significant differences
# Co_Single in Putamen (right) T values is:-3.974254694721207
# Co_Single in Putamen (right) p values is:7.104936671264994e-05
# Co_Single in Hippocampus (left) are significant differences
# Co_Single in Hippocampus (left) T values is:-3.7436771054972815
# Co_Single in Hippocampus (left) p values is:0.0001822675799207918
# Co_Single in Hippocampus (right) are significant differences
# Co_Single in Hippocampus (right) T values is:-3.4006075174994583
# Co_Single in Hippocampus (right) p values is:0.0006747453961157834
# Co_Single in Amygdala (left) are significant differences
# Co_Single in Amygdala (left) T values is:-7.920606597991539
# Co_Single in Amygdala (left) p values is:2.55351295663786e-15
# Co_Single in Amygdala (right) are significant differences
# Co_Single in Amygdala (right) T values is:-7.5648576726437975
# Co_Single in Amygdala (right) p values is:4.196643033083092e-14
# Co_Single in Ventral Striatum (left) are significant differences
# Co_Single in Ventral Striatum (left) T values is:-5.367614823804212
# Co_Single in Ventral Striatum (left) p values is:8.140085228092175e-08
# Co_Single in Ventral Striatum (right) are significant differences
# Co_Single in Ventral Striatum (right) T values is:-6.066908242696822
# Co_Single in Ventral Striatum (right) p values is:1.346714961769635e-09
# Co_Single in I-IV Cerebellum (left) are significant differences
# Co_Single in I-IV Cerebellum (left) T values is:-3.291191608469653
# Co_Single in I-IV Cerebellum (left) p values is:0.001000770327831857
# Co_Single in I-IV Cerebellum (right) are significant differences
# Co_Single in I-IV Cerebellum (right) T values is:-3.252302490950976
# Co_Single in I-IV Cerebellum (right) p values is:0.0011481792640557487
# Co_Single in V Cerebellum (left) are significant differences
# Co_Single in V Cerebellum (left) T values is:-5.645630043414589
# Co_Single in V Cerebellum (left) p values is:1.6864055929488586e-08
# Co_Single in V Cerebellum (right) are significant differences
# Co_Single in V Cerebellum (right) T values is:-5.598340922675382
# Co_Single in V Cerebellum (right) p values is:2.215821504059079e-08
# Co_Single in VI Cerebellum (left) are significant differences
# Co_Single in VI Cerebellum (left) T values is:-6.555458592652094
# Co_Single in VI Cerebellum (left) p values is:5.794564827965587e-11
# Co_Single in VI Cerebellum (vermis) are significant differences
# Co_Single in VI Cerebellum (vermis) T values is:-4.935168639659751
# Co_Single in VI Cerebellum (vermis) p values is:8.125125465774374e-07
# Co_Single in VI Cerebellum (right) are significant differences
# Co_Single in VI Cerebellum (right) T values is:-6.47783983230731
# Co_Single in VI Cerebellum (right) p values is:9.700307224136395e-11
# Co_Single in Crus I Cerebellum (left) are significant differences
# Co_Single in Crus I Cerebellum (left) T values is:-6.121823059854376
# Co_Single in Crus I Cerebellum (left) p values is:9.565419567536537e-10
# Co_Single in Crus I Cerebellum (right) are significant differences
# Co_Single in Crus I Cerebellum (right) T values is:-5.854087226000628
# Co_Single in Crus I Cerebellum (right) p values is:4.9329446083490325e-09
# Co_Single in Crus II Cerebellum (left) are significant differences
# Co_Single in Crus II Cerebellum (left) T values is:-5.420811445665247
# Co_Single in Crus II Cerebellum (left) p values is:6.05781488305368e-08
# Co_Single in Crus II Cerebellum (vermis) are significant differences
# Co_Single in Crus II Cerebellum (vermis) T values is:-2.6238035526178662
# Co_Single in Crus II Cerebellum (vermis) p values is:0.008707356771474273
# Co_Single in Crus II Cerebellum (right) are significant differences
# Co_Single in Crus II Cerebellum (right) T values is:-5.2941538876166385
# Co_Single in Crus II Cerebellum (right) p values is:1.2186380415890596e-07
# Co_Single in VIIb Cerebellum (left) are significant differences
# Co_Single in VIIb Cerebellum (left) T values is:-6.730876285098867
# Co_Single in VIIb Cerebellum (left) p values is:1.7700507726203796e-11
# Co_Single in VIIb Cerebellum (vermis) are significant differences
# Co_Single in VIIb Cerebellum (vermis) T values is:-5.071108524171408
# Co_Single in VIIb Cerebellum (vermis) p values is:4.019248570630296e-07
# Co_Single in VIIb Cerebellum (right) are significant differences
# Co_Single in VIIb Cerebellum (right) T values is:-6.697056980465147
# Co_Single in VIIb Cerebellum (right) p values is:2.2299162516503657e-11
# Co_Single in VIIIa Cerebellum (left) are significant differences
# Co_Single in VIIIa Cerebellum (left) T values is:-8.567664318328758
# Co_Single in VIIIa Cerebellum (left) p values is:1.1102230246251565e-16
# Co_Single in VIIIa Cerebellum (vermis) are significant differences
# Co_Single in VIIIa Cerebellum (vermis) T values is:-5.994695173951664
# Co_Single in VIIIa Cerebellum (vermis) p values is:2.1024280094650294e-09
# Co_Single in VIIIa Cerebellum (right) are significant differences
# Co_Single in VIIIa Cerebellum (right) T values is:-9.165800404183187
# Co_Single in VIIIa Cerebellum (right) p values is:1.1102230246251565e-16
# Co_Single in VIIIb Cerebellum (left) are significant differences
# Co_Single in VIIIb Cerebellum (left) T values is:-7.343894963092488
# Co_Single in VIIIb Cerebellum (left) p values is:2.220446049250313e-13
# Co_Single in VIIIb Cerebellum (vermis) are significant differences
# Co_Single in VIIIb Cerebellum (vermis) T values is:-5.541172479828829
# Co_Single in VIIIb Cerebellum (vermis) p values is:3.073465748570925e-08
# Co_Single in VIIIb Cerebellum (right) are significant differences
# Co_Single in VIIIb Cerebellum (right) T values is:-8.02501991302588
# Co_Single in VIIIb Cerebellum (right) p values is:1.1102230246251565e-15
# Co_Single in IX Cerebellum (left) are significant differences
# Co_Single in IX Cerebellum (left) T values is:-5.987440881805182
# Co_Single in IX Cerebellum (left) p values is:2.1980273157140573e-09
# Co_Single in IX Cerebellum (vermis) are significant differences
# Co_Single in IX Cerebellum (vermis) T values is:-5.178971048806221
# Co_Single in IX Cerebellum (vermis) p values is:2.270436689766342e-07
# Co_Single in IX Cerebellum (right) are significant differences
# Co_Single in IX Cerebellum (right) T values is:-6.587141216313673
# Co_Single in IX Cerebellum (right) p values is:4.68766137018406e-11
# Co_Single in X Cerebellum (left) are significant differences
# Co_Single in X Cerebellum (left) T values is:-2.106776500847909
# Co_Single in X Cerebellum (left) p values is:0.03515946386559865
# Co_Single in X Cerebellum (vermis) are significant differences
# Co_Single in X Cerebellum (vermis) T values is:-2.8848666933702374
# Co_Single in X Cerebellum (vermis) p values is:0.003923374144704117
# Co_HC in Frontal Pole (left) are significant differences
# Co_HC in Frontal Pole (left) T values is:-6.8593874810961415
# Co_HC in Frontal Pole (left) p values is:7.059131057474133e-12
# Co_HC in Frontal Pole (right) are significant differences
# Co_HC in Frontal Pole (right) T values is:-6.603656683896749
# Co_HC in Frontal Pole (right) p values is:4.083022808742953e-11
# Co_HC in Insular Cortex (left) are significant differences
# Co_HC in Insular Cortex (left) T values is:-7.525082673168006
# Co_HC in Insular Cortex (left) p values is:5.4289905904170155e-14
# Co_HC in Insular Cortex (right) are significant differences
# Co_HC in Insular Cortex (right) T values is:-7.693621233134895
# Co_HC in Insular Cortex (right) p values is:1.4765966227514582e-14
# Co_HC in Superior Frontal Gyrus (left) are significant differences
# Co_HC in Superior Frontal Gyrus (left) T values is:-3.304937089654
# Co_HC in Superior Frontal Gyrus (left) p values is:0.0009511680693605751
# Co_HC in Superior Frontal Gyrus (right) are significant differences
# Co_HC in Superior Frontal Gyrus (right) T values is:-3.490908894204307
# Co_HC in Superior Frontal Gyrus (right) p values is:0.0004821199849562863
# Co_HC in Middle Frontal Gyrus (left) are significant differences
# Co_HC in Middle Frontal Gyrus (left) T values is:-2.1366057754493992
# Co_HC in Middle Frontal Gyrus (left) p values is:0.032638697120206395
# Co_HC in Middle Frontal Gyrus (right) are significant differences
# Co_HC in Middle Frontal Gyrus (right) T values is:-2.1477247550344907
# Co_HC in Middle Frontal Gyrus (right) p values is:0.03174416851478001
# Co_HC in Inferior Frontal Gyrus, pars opercularis (right) are significant differences
# Co_HC in Inferior Frontal Gyrus, pars opercularis (right) T values is:-2.6409580344012618
# Co_HC in Inferior Frontal Gyrus, pars opercularis (right) p values is:0.008271777053039497
# Co_HC in Precentral Gyrus (left) are significant differences
# Co_HC in Precentral Gyrus (left) T values is:-6.414315872742374
# Co_HC in Precentral Gyrus (left) p values is:1.437092667089246e-10
# Co_HC in Precentral Gyrus (right) are significant differences
# Co_HC in Precentral Gyrus (right) T values is:-8.46530418254561
# Co_HC in Precentral Gyrus (right) p values is:1.1102230246251565e-16
# Co_HC in Temporal Pole (left) are significant differences
# Co_HC in Temporal Pole (left) T values is:-6.10209229784453
# Co_HC in Temporal Pole (left) p values is:1.0605907263538938e-09
# Co_HC in Temporal Pole (right) are significant differences
# Co_HC in Temporal Pole (right) T values is:-7.1001220579075
# Co_HC in Temporal Pole (right) p values is:1.276090344504155e-12
# Co_HC in Superior Temporal Gyrus, anterior division (left) are significant differences
# Co_HC in Superior Temporal Gyrus, anterior division (left) T values is:-4.931515558853307
# Co_HC in Superior Temporal Gyrus, anterior division (left) p values is:8.206010730926749e-07
# Co_HC in Superior Temporal Gyrus, anterior division (right) are significant differences
# Co_HC in Superior Temporal Gyrus, anterior division (right) T values is:-6.8941504702306515
# Co_HC in Superior Temporal Gyrus, anterior division (right) p values is:5.533462577034243e-12
# Co_HC in Superior Temporal Gyrus, posterior division (left) are significant differences
# Co_HC in Superior Temporal Gyrus, posterior division (left) T values is:-5.342942064994272
# Co_HC in Superior Temporal Gyrus, posterior division (left) p values is:9.216245766552333e-08
# Co_HC in Superior Temporal Gyrus, posterior division (right) are significant differences
# Co_HC in Superior Temporal Gyrus, posterior division (right) T values is:-5.769769193524515
# Co_HC in Superior Temporal Gyrus, posterior division (right) p values is:8.021454722673127e-09
# Co_HC in Middle Temporal Gyrus, anterior division (left) are significant differences
# Co_HC in Middle Temporal Gyrus, anterior division (left) T values is:-6.971954178005035
# Co_HC in Middle Temporal Gyrus, anterior division (left) p values is:3.194888797963813e-12
# Co_HC in Middle Temporal Gyrus, anterior division (right) are significant differences
# Co_HC in Middle Temporal Gyrus, anterior division (right) T values is:-5.930083140596706
# Co_HC in Middle Temporal Gyrus, anterior division (right) p values is:3.063240217038299e-09
# Co_HC in Middle Temporal Gyrus, posterior division (left) are significant differences
# Co_HC in Middle Temporal Gyrus, posterior division (left) T values is:-6.1369609312423234
# Co_HC in Middle Temporal Gyrus, posterior division (left) p values is:8.524086991812396e-10
# Co_HC in Middle Temporal Gyrus, posterior division (right) are significant differences
# Co_HC in Middle Temporal Gyrus, posterior division (right) T values is:-5.516428090007811
# Co_HC in Middle Temporal Gyrus, posterior division (right) p values is:3.490109912185346e-08
# Co_HC in Middle Temporal Gyrus, temporooccipital part (left) are significant differences
# Co_HC in Middle Temporal Gyrus, temporooccipital part (left) T values is:-2.379359983902534
# Co_HC in Middle Temporal Gyrus, temporooccipital part (left) p values is:0.017349378032498253
# Co_HC in Middle Temporal Gyrus, temporooccipital part (right) are significant differences
# Co_HC in Middle Temporal Gyrus, temporooccipital part (right) T values is:-4.015572948797172
# Co_HC in Middle Temporal Gyrus, temporooccipital part (right) p values is:5.945582592925547e-05
# Co_HC in Inferior Temporal Gyrus, anterior division (left) are significant differences
# Co_HC in Inferior Temporal Gyrus, anterior division (left) T values is:-5.309458253623231
# Co_HC in Inferior Temporal Gyrus, anterior division (left) p values is:1.1078749584392256e-07
# Co_HC in Inferior Temporal Gyrus, anterior division (right) are significant differences
# Co_HC in Inferior Temporal Gyrus, anterior division (right) T values is:-4.53682451295612
# Co_HC in Inferior Temporal Gyrus, anterior division (right) p values is:5.734419822878145e-06
# Co_HC in Inferior Temporal Gyrus, posterior division (left) are significant differences
# Co_HC in Inferior Temporal Gyrus, posterior division (left) T values is:-3.2775116332985728
# Co_HC in Inferior Temporal Gyrus, posterior division (left) p values is:0.0010485370980165554
# Co_HC in Inferior Temporal Gyrus, posterior division (right) are significant differences
# Co_HC in Inferior Temporal Gyrus, posterior division (right) T values is:-4.37777235968689
# Co_HC in Inferior Temporal Gyrus, posterior division (right) p values is:1.2033180835535617e-05
# Co_HC in Postcentral Gyrus (left) are significant differences
# Co_HC in Postcentral Gyrus (left) T values is:-6.510365004162721
# Co_HC in Postcentral Gyrus (left) p values is:7.623424114200361e-11
# Co_HC in Postcentral Gyrus (right) are significant differences
# Co_HC in Postcentral Gyrus (right) T values is:-7.78563200752895
# Co_HC in Postcentral Gyrus (right) p values is:7.216449660063518e-15
# Co_HC in Superior Parietal Lobule (left) are significant differences
# Co_HC in Superior Parietal Lobule (left) T values is:-4.161290456581735
# Co_HC in Superior Parietal Lobule (left) p values is:3.173968732361754e-05
# Co_HC in Superior Parietal Lobule (right) are significant differences
# Co_HC in Superior Parietal Lobule (right) T values is:-4.502491539275126
# Co_HC in Superior Parietal Lobule (right) p values is:6.743170908873886e-06
# Co_HC in Supramarginal Gyrus, anterior division (left) are significant differences
# Co_HC in Supramarginal Gyrus, anterior division (left) T values is:-3.0517481106034223
# Co_HC in Supramarginal Gyrus, anterior division (left) p values is:0.0022772560177490853
# Co_HC in Supramarginal Gyrus, anterior division (right) are significant differences
# Co_HC in Supramarginal Gyrus, anterior division (right) T values is:-4.6963948110168445
# Co_HC in Supramarginal Gyrus, anterior division (right) p values is:2.6604636437221885e-06
# Co_HC in Supramarginal Gyrus, posterior division (left) are significant differences
# Co_HC in Supramarginal Gyrus, posterior division (left) T values is:-3.006558216113404
# Co_HC in Supramarginal Gyrus, posterior division (left) p values is:0.002644573268910211
# Co_HC in Supramarginal Gyrus, posterior division (right) are significant differences
# Co_HC in Supramarginal Gyrus, posterior division (right) T values is:-3.830621652827067
# Co_HC in Supramarginal Gyrus, posterior division (right) p values is:0.0001280981445609397
# Co_HC in Angular Gyrus (left) are significant differences
# Co_HC in Angular Gyrus (left) T values is:-2.0903022092194115
# Co_HC in Angular Gyrus (left) p values is:0.036599641983356856
# Co_HC in Angular Gyrus (right) are significant differences
# Co_HC in Angular Gyrus (right) T values is:-3.892287213563853
# Co_HC in Angular Gyrus (right) p values is:9.953316989286254e-05
# Co_HC in Lateral Occipital Cortex, superior division (left) are significant differences
# Co_HC in Lateral Occipital Cortex, superior division (left) T values is:-7.02213209991929
# Co_HC in Lateral Occipital Cortex, superior division (left) p values is:2.23487894857044e-12
# Co_HC in Lateral Occipital Cortex, superior division (right) are significant differences
# Co_HC in Lateral Occipital Cortex, superior division (right) T values is:-5.142341979979745
# Co_HC in Lateral Occipital Cortex, superior division (right) p values is:2.7315683126527546e-07
# Co_HC in Lateral Occipital Cortex, inferior division (left) are significant differences
# Co_HC in Lateral Occipital Cortex, inferior division (left) T values is:-3.9719355167583537
# Co_HC in Lateral Occipital Cortex, inferior division (left) p values is:7.146896447551843e-05
# Co_HC in Lateral Occipital Cortex, inferior division (right) are significant differences
# Co_HC in Lateral Occipital Cortex, inferior division (right) T values is:-3.3324232608629663
# Co_HC in Lateral Occipital Cortex, inferior division (right) p values is:0.0008620449702241295
# Co_HC in Intracalcarine Cortex (left) are significant differences
# Co_HC in Intracalcarine Cortex (left) T values is:-2.917147858624873
# Co_HC in Intracalcarine Cortex (left) p values is:0.003535283815874757
# Co_HC in Intracalcarine Cortex (right) are significant differences
# Co_HC in Intracalcarine Cortex (right) T values is:-3.7103159789507987
# Co_HC in Intracalcarine Cortex (right) p values is:0.00020740029638832702
# Co_HC in Frontal Medial Cortex (left) are significant differences
# Co_HC in Frontal Medial Cortex (left) T values is:-5.6218092567375715
# Co_HC in Frontal Medial Cortex (left) p values is:1.9076252022465212e-08
# Co_HC in Frontal Medial Cortex (right) are significant differences
# Co_HC in Frontal Medial Cortex (right) T values is:-5.520542821423845
# Co_HC in Frontal Medial Cortex (right) p values is:3.409441129420543e-08
# Co_HC in Juxtapositional Lobule Cortex (left) are significant differences
# Co_HC in Juxtapositional Lobule Cortex (left) T values is:-4.106236084664448
# Co_HC in Juxtapositional Lobule Cortex (left) p values is:4.032971860934431e-05
# Co_HC in Juxtapositional Lobule Cortex(right) are significant differences
# Co_HC in Juxtapositional Lobule Cortex(right) T values is:-4.686149596089085
# Co_HC in Juxtapositional Lobule Cortex(right) p values is:2.796990057674087e-06
# Co_HC in Subcallosal Cortex (left) are significant differences
# Co_HC in Subcallosal Cortex (left) T values is:-6.0269880561984
# Co_HC in Subcallosal Cortex (left) p values is:1.6912597988749667e-09
# Co_HC in Subcallosal Cortex (right) are significant differences
# Co_HC in Subcallosal Cortex (right) T values is:-4.424927774251101
# Co_HC in Subcallosal Cortex (right) p values is:9.683780709868195e-06
# Co_HC in Paracingulate Gyrus (left) are significant differences
# Co_HC in Paracingulate Gyrus (left) T values is:-4.574146644378724
# Co_HC in Paracingulate Gyrus (left) p values is:4.802092657185675e-06
# Co_HC in Paracingulate Gyrus (right) are significant differences
# Co_HC in Paracingulate Gyrus (right) T values is:-5.227822090453003
# Co_HC in Paracingulate Gyrus (right) p values is:1.7274632047037386e-07
# Co_HC in Cingulate Gyrus, posterior division (left) are significant differences
# Co_HC in Cingulate Gyrus, posterior division (left) T values is:-3.347493153988646
# Co_HC in Cingulate Gyrus, posterior division (left) p values is:0.0008165318968332835
# Co_HC in Cingulate Gyrus, posterior division (right) are significant differences
# Co_HC in Cingulate Gyrus, posterior division (right) T values is:-3.0181693149908053
# Co_HC in Cingulate Gyrus, posterior division (right) p values is:0.0025453506389232494
# Co_HC in Precuneous Cortex (left) are significant differences
# Co_HC in Precuneous Cortex (left) T values is:-5.741846656374362
# Co_HC in Precuneous Cortex (left) p values is:9.461548211575632e-09
# Co_HC in Precuneous Cortex (right) are significant differences
# Co_HC in Precuneous Cortex (right) T values is:-6.262698297293626
# Co_HC in Precuneous Cortex (right) p values is:3.8385639111737646e-10
# Co_HC in Cuneal Cortex (left) are significant differences
# Co_HC in Cuneal Cortex (left) T values is:-3.0208986097462587
# Co_HC in Cuneal Cortex (left) p values is:0.0025225272373012864
# Co_HC in Cuneal Cortex (right) are significant differences
# Co_HC in Cuneal Cortex (right) T values is:-3.2196448647159355
# Co_HC in Cuneal Cortex (right) p values is:0.0012849556537930518
# Co_HC in Frontal Orbital Cortex (left) are significant differences
# Co_HC in Frontal Orbital Cortex (left) T values is:-7.562115629995081
# Co_HC in Frontal Orbital Cortex (left) p values is:4.085620730620576e-14
# Co_HC in Frontal Orbital Cortex (right) are significant differences
# Co_HC in Frontal Orbital Cortex (right) T values is:-6.027891341061093
# Co_HC in Frontal Orbital Cortex (right) p values is:1.681849104429034e-09
# Co_HC in Parahippocampal Gyrus, anterior division (left) are significant differences
# Co_HC in Parahippocampal Gyrus, anterior division (left) T values is:-7.781121497841303
# Co_HC in Parahippocampal Gyrus, anterior division (left) p values is:7.438494264988549e-15
# Co_HC in Parahippocampal Gyrus, anterior division (right) are significant differences
# Co_HC in Parahippocampal Gyrus, anterior division (right) T values is:-8.008564161148978
# Co_HC in Parahippocampal Gyrus, anterior division (right) p values is:1.2212453270876722e-15
# Co_HC in Parahippocampal Gyrus, posterior division (left) are significant differences
# Co_HC in Parahippocampal Gyrus, posterior division (left) T values is:-3.5377754668768566
# Co_HC in Parahippocampal Gyrus, posterior division (left) p values is:0.00040416465408610325
# Co_HC in Parahippocampal Gyrus, posterior division (right) are significant differences
# Co_HC in Parahippocampal Gyrus, posterior division (right) T values is:-4.114061607393091
# Co_HC in Parahippocampal Gyrus, posterior division (right) p values is:3.898663801826796e-05
# Co_HC in Lingual Gyrus (left) are significant differences
# Co_HC in Lingual Gyrus (left) T values is:-6.937789891384673
# Co_HC in Lingual Gyrus (left) p values is:4.069300452158586e-12
# Co_HC in Lingual Gyrus (right) are significant differences
# Co_HC in Lingual Gyrus (right) T values is:-8.393986670593854
# Co_HC in Lingual Gyrus (right) p values is:1.1102230246251565e-16
# Co_HC in Temporal Fusiform Cortex, anterior division (left) are significant differences
# Co_HC in Temporal Fusiform Cortex, anterior division (left) T values is:-10.984163430348376
# Co_HC in Temporal Fusiform Cortex, anterior division (left) p values is:1.1102230246251565e-16
# Co_HC in Temporal Fusiform Cortex, anterior division (right) are significant differences
# Co_HC in Temporal Fusiform Cortex, anterior division (right) T values is:-9.268260563872143
# Co_HC in Temporal Fusiform Cortex, anterior division (right) p values is:1.1102230246251565e-16
# Co_HC in Temporal Fusiform Cortex, posterior division (left) are significant differences
# Co_HC in Temporal Fusiform Cortex, posterior division (left) T values is:-4.880628890721879
# Co_HC in Temporal Fusiform Cortex, posterior division (left) p values is:1.0632836777713095e-06
# Co_HC in Temporal Fusiform Cortex, posterior division (right) are significant differences
# Co_HC in Temporal Fusiform Cortex, posterior division (right) T values is:-7.575376043579314
# Co_HC in Temporal Fusiform Cortex, posterior division (right) p values is:3.68594044175552e-14
# Co_HC in Temporal Occipital Fusiform Cortex (left) are significant differences
# Co_HC in Temporal Occipital Fusiform Cortex (left) T values is:-3.7470975586843576
# Co_HC in Temporal Occipital Fusiform Cortex (left) p values is:0.00017925089047554632
# Co_HC in Temporal Occipital Fusiform Cortex (right) are significant differences
# Co_HC in Temporal Occipital Fusiform Cortex (right) T values is:-4.591490664027997
# Co_HC in Temporal Occipital Fusiform Cortex (right) p values is:4.420004881766637e-06
# Co_HC in Occipital Fusiform Gyrus (left) are significant differences
# Co_HC in Occipital Fusiform Gyrus (left) T values is:-4.712227254767691
# Co_HC in Occipital Fusiform Gyrus (left) p values is:2.461983418911018e-06
# Co_HC in Occipital Fusiform Gyrus (right) are significant differences
# Co_HC in Occipital Fusiform Gyrus (right) T values is:-6.247291871524879
# Co_HC in Occipital Fusiform Gyrus (right) p values is:4.236250239486594e-10
# Co_HC in Frontal Operculum Cortex (left) are significant differences
# Co_HC in Frontal Operculum Cortex (left) T values is:-4.488780859899334
# Co_HC in Frontal Operculum Cortex (left) p values is:7.191685908791712e-06
# Co_HC in Frontal Operculum Cortex (right) are significant differences
# Co_HC in Frontal Operculum Cortex (right) T values is:-4.626861253319488
# Co_HC in Frontal Operculum Cortex (right) p values is:3.729077165837147e-06
# Co_HC in Central Opercular Cortex (left) are significant differences
# Co_HC in Central Opercular Cortex (left) T values is:-5.775018388399738
# Co_HC in Central Opercular Cortex (left) p values is:7.775632915318909e-09
# Co_HC in Central Opercular Cortex (right) are significant differences
# Co_HC in Central Opercular Cortex (right) T values is:-7.822012273181905
# Co_HC in Central Opercular Cortex (right) p values is:5.329070518200751e-15
# Co_HC in Parietal Operculum Cortex (left) are significant differences
# Co_HC in Parietal Operculum Cortex (left) T values is:-4.950737650530851
# Co_HC in Parietal Operculum Cortex (left) p values is:7.43613869702564e-07
# Co_HC in Parietal Operculum Cortex (right) are significant differences
# Co_HC in Parietal Operculum Cortex (right) T values is:-4.001609235797876
# Co_HC in Parietal Operculum Cortex (right) p values is:6.30746614371791e-05
# Co_HC in Planum Polare (left) are significant differences
# Co_HC in Planum Polare (left) T values is:-6.784801851462018
# Co_HC in Planum Polare (left) p values is:1.1855627590762197e-11
# Co_HC in Planum Polare (right) are significant differences
# Co_HC in Planum Polare (right) T values is:-8.46960013062114
# Co_HC in Planum Polare (right) p values is:1.1102230246251565e-16
# Co_HC in Heschl's Gyrus (includes H1 and H2) (left) are significant differences
# Co_HC in Heschl's Gyrus (includes H1 and H2) (left) T values is:-6.405804146417514
# Co_HC in Heschl's Gyrus (includes H1 and H2) (left) p values is:1.519484538192728e-10
# Co_HC in Heschl's Gyrus (includes H1 and H2) (right) are significant differences
# Co_HC in Heschl's Gyrus (includes H1 and H2) (right) T values is:-8.141142917809765
# Co_HC in Heschl's Gyrus (includes H1 and H2) (right) p values is:4.440892098500626e-16
# Co_HC in Planum Temporale (left) are significant differences
# Co_HC in Planum Temporale (left) T values is:-4.096169164616626
# Co_HC in Planum Temporale (left) p values is:4.212213732068815e-05
# Co_HC in Planum Temporale (right) are significant differences
# Co_HC in Planum Temporale (right) T values is:-5.744178714930162
# Co_HC in Planum Temporale (right) p values is:9.332236206027744e-09
# Co_HC in Occipital Pole (left) are significant differences
# Co_HC in Occipital Pole (left) T values is:-3.3500073183374948
# Co_HC in Occipital Pole (left) p values is:0.0008091594116774736
# Co_HC in Occipital Pole (right) are significant differences
# Co_HC in Occipital Pole (right) T values is:-2.908793754495047
# Co_HC in Occipital Pole (right) p values is:0.0036311085314256752
# Co_HC in Thalamus (right) are significant differences
# Co_HC in Thalamus (right) T values is:2.337194883873322
# Co_HC in Thalamus (right) p values is:0.019436050448321418
# Co_HC in Caudate (left) are significant differences
# Co_HC in Caudate (left) T values is:6.477233565922064
# Co_HC in Caudate (left) p values is:9.49654799242694e-11
# Co_HC in Caudate (right) are significant differences
# Co_HC in Caudate (right) T values is:6.533004381502455
# Co_HC in Caudate (right) p values is:6.55666632098928e-11
# Co_HC in Putamen (right) are significant differences
# Co_HC in Putamen (right) T values is:-3.633405484530836
# Co_HC in Putamen (right) p values is:0.0002802040332441358
# Co_HC in Pallidum (right) are significant differences
# Co_HC in Pallidum (right) T values is:2.2151559537160765
# Co_HC in Pallidum (right) p values is:0.026757364679031004
# Co_HC in Hippocampus (left) are significant differences
# Co_HC in Hippocampus (left) T values is:-8.389914255855965
# Co_HC in Hippocampus (left) p values is:1.1102230246251565e-16
# Co_HC in Hippocampus (right) are significant differences
# Co_HC in Hippocampus (right) T values is:-7.007326313868063
# Co_HC in Hippocampus (right) p values is:2.4840129952963252e-12
# Co_HC in Amygdala (left) are significant differences
# Co_HC in Amygdala (left) T values is:-12.931664632628173
# Co_HC in Amygdala (left) p values is:1.1102230246251565e-16
# Co_HC in Amygdala (right) are significant differences
# Co_HC in Amygdala (right) T values is:-12.787342373220369
# Co_HC in Amygdala (right) p values is:1.1102230246251565e-16
# Co_HC in Ventral Striatum (left) are significant differences
# Co_HC in Ventral Striatum (left) T values is:-7.9413283854472
# Co_HC in Ventral Striatum (left) p values is:2.1094237467877974e-15
# Co_HC in Ventral Striatum (right) are significant differences
# Co_HC in Ventral Striatum (right) T values is:-9.157349242902198
# Co_HC in Ventral Striatum (right) p values is:1.1102230246251565e-16
# Co_HC in I-IV Cerebellum (left) are significant differences
# Co_HC in I-IV Cerebellum (left) T values is:-4.932313731045473
# Co_HC in I-IV Cerebellum (left) p values is:8.172568781716905e-07
# Co_HC in I-IV Cerebellum (right) are significant differences
# Co_HC in I-IV Cerebellum (right) T values is:-4.359686548520445
# Co_HC in I-IV Cerebellum (right) p values is:1.3071222174199093e-05
# Co_HC in V Cerebellum (left) are significant differences
# Co_HC in V Cerebellum (left) T values is:-8.494185717941484
# Co_HC in V Cerebellum (left) p values is:1.1102230246251565e-16
# Co_HC in V Cerebellum (right) are significant differences
# Co_HC in V Cerebellum (right) T values is:-8.417633741979904
# Co_HC in V Cerebellum (right) p values is:1.1102230246251565e-16
# Co_HC in VI Cerebellum (left) are significant differences
# Co_HC in VI Cerebellum (left) T values is:-10.566631532331654
# Co_HC in VI Cerebellum (left) p values is:1.1102230246251565e-16
# Co_HC in VI Cerebellum (vermis) are significant differences
# Co_HC in VI Cerebellum (vermis) T values is:-6.865157568128692
# Co_HC in VI Cerebellum (vermis) p values is:6.780132011385831e-12
# Co_HC in VI Cerebellum (right) are significant differences
# Co_HC in VI Cerebellum (right) T values is:-10.071263513193719
# Co_HC in VI Cerebellum (right) p values is:1.1102230246251565e-16
# Co_HC in Crus I Cerebellum (left) are significant differences
# Co_HC in Crus I Cerebellum (left) T values is:-9.683196822347712
# Co_HC in Crus I Cerebellum (left) p values is:1.1102230246251565e-16
# Co_HC in Crus I Cerebellum (right) are significant differences
# Co_HC in Crus I Cerebellum (right) T values is:-9.460469701721568
# Co_HC in Crus I Cerebellum (right) p values is:1.1102230246251565e-16
# Co_HC in Crus II Cerebellum (left) are significant differences
# Co_HC in Crus II Cerebellum (left) T values is:-10.602113275230705
# Co_HC in Crus II Cerebellum (left) p values is:1.1102230246251565e-16
# Co_HC in Crus II Cerebellum (vermis) are significant differences
# Co_HC in Crus II Cerebellum (vermis) T values is:-5.076721466202477
# Co_HC in Crus II Cerebellum (vermis) p values is:3.86456872392138e-07
# Co_HC in Crus II Cerebellum (right) are significant differences
# Co_HC in Crus II Cerebellum (right) T values is:-10.145896615807898
# Co_HC in Crus II Cerebellum (right) p values is:1.1102230246251565e-16
# Co_HC in VIIb Cerebellum (left) are significant differences
# Co_HC in VIIb Cerebellum (left) T values is:-12.60423858365042
# Co_HC in VIIb Cerebellum (left) p values is:1.1102230246251565e-16
# Co_HC in VIIb Cerebellum (vermis) are significant differences
# Co_HC in VIIb Cerebellum (vermis) T values is:-7.294966064853996
# Co_HC in VIIb Cerebellum (vermis) p values is:3.0664359940146824e-13
# Co_HC in VIIb Cerebellum (right) are significant differences
# Co_HC in VIIb Cerebellum (right) T values is:-12.412910975744854
# Co_HC in VIIb Cerebellum (right) p values is:1.1102230246251565e-16
# Co_HC in VIIIa Cerebellum (left) are significant differences
# Co_HC in VIIIa Cerebellum (left) T values is:-15.063216236832837
# Co_HC in VIIIa Cerebellum (left) p values is:1.1102230246251565e-16
# Co_HC in VIIIa Cerebellum (vermis) are significant differences
# Co_HC in VIIIa Cerebellum (vermis) T values is:-9.855449705341679
# Co_HC in VIIIa Cerebellum (vermis) p values is:1.1102230246251565e-16
# Co_HC in VIIIa Cerebellum (right) are significant differences
# Co_HC in VIIIa Cerebellum (right) T values is:-16.156201199193344
# Co_HC in VIIIa Cerebellum (right) p values is:1.1102230246251565e-16
# Co_HC in VIIIb Cerebellum (left) are significant differences
# Co_HC in VIIIb Cerebellum (left) T values is:-12.725118046212978
# Co_HC in VIIIb Cerebellum (left) p values is:1.1102230246251565e-16
# Co_HC in VIIIb Cerebellum (vermis) are significant differences
# Co_HC in VIIIb Cerebellum (vermis) T values is:-9.591791369376272
# Co_HC in VIIIb Cerebellum (vermis) p values is:1.1102230246251565e-16
# Co_HC in VIIIb Cerebellum (right) are significant differences
# Co_HC in VIIIb Cerebellum (right) T values is:-13.537491416526759
# Co_HC in VIIIb Cerebellum (right) p values is:1.1102230246251565e-16
# Co_HC in IX Cerebellum (left) are significant differences
# Co_HC in IX Cerebellum (left) T values is:-9.687333737684813
# Co_HC in IX Cerebellum (left) p values is:1.1102230246251565e-16
# Co_HC in IX Cerebellum (vermis) are significant differences
# Co_HC in IX Cerebellum (vermis) T values is:-7.921857550945551
# Co_HC in IX Cerebellum (vermis) p values is:2.4424906541753444e-15
# Co_HC in IX Cerebellum (right) are significant differences
# Co_HC in IX Cerebellum (right) T values is:-11.056625289923339
# Co_HC in IX Cerebellum (right) p values is:1.1102230246251565e-16
# Co_HC in X Cerebellum (left) are significant differences
# Co_HC in X Cerebellum (left) T values is:-5.562257266071794
# Co_HC in X Cerebellum (left) p values is:2.6873362646284704e-08
# ...
# Single_HC in Superior Parietal Lobule (left) p values is:0.011486679334011596
# Single_HC in Superior Parietal Lobule (right) are significant differences
# Single_HC in Superior Parietal Lobule (right) T values is:-3.555378809241544
# Single_HC in Superior Parietal Lobule (right) p values is:0.0003779964017073256
# Single_HC in Supramarginal Gyrus, anterior division (left) are significant differences
# Single_HC in Supramarginal Gyrus, anterior division (left) T values is:-2.059233538122332
# Single_HC in Supramarginal Gyrus, anterior division (left) p values is:0.03948020100783889
# Single_HC in Supramarginal Gyrus, posterior division (right) are significant differences
# Single_HC in Supramarginal Gyrus, posterior division (right) T values is:-2.2890512629604247
# Single_HC in Supramarginal Gyrus, posterior division (right) p values is:0.022083063152093962
# Single_HC in Angular Gyrus (right) are significant differences
# Single_HC in Angular Gyrus (right) T values is:-2.769809917875916
# Single_HC in Angular Gyrus (right) p values is:0.005612235965431145
# Single_HC in Lateral Occipital Cortex, superior division (left) are significant differences
# Single_HC in Lateral Occipital Cortex, superior division (left) T values is:-4.78288283115188
# Single_HC in Lateral Occipital Cortex, superior division (left) p values is:1.7359191774035665e-06
# Single_HC in Lateral Occipital Cortex, superior division (right) are significant differences
# Single_HC in Lateral Occipital Cortex, superior division (right) T values is:-3.538838213342749
# Single_HC in Lateral Occipital Cortex, superior division (right) p values is:0.00040247964796025215
# Single_HC in Lateral Occipital Cortex, inferior division (left) are significant differences
# Single_HC in Lateral Occipital Cortex, inferior division (left) T values is:-2.1036276241361547
# Single_HC in Lateral Occipital Cortex, inferior division (left) p values is:0.03541897371989289
# Single_HC in Lateral Occipital Cortex, inferior division (right) are significant differences
# Single_HC in Lateral Occipital Cortex, inferior division (right) T values is:-2.12580065170092
# Single_HC in Lateral Occipital Cortex, inferior division (right) p values is:0.03352773990009894
# Single_HC in Juxtapositional Lobule Cortex(right) are significant differences
# Single_HC in Juxtapositional Lobule Cortex(right) T values is:-3.234580350086922
# Single_HC in Juxtapositional Lobule Cortex(right) p values is:0.0012194917816035211
# Single_HC in Subcallosal Cortex (left) are significant differences
# Single_HC in Subcallosal Cortex (left) T values is:-4.217566955799804
# Single_HC in Subcallosal Cortex (left) p values is:2.4765255063896596e-05
# Single_HC in Subcallosal Cortex (right) are significant differences
# Single_HC in Subcallosal Cortex (right) T values is:-2.880011882797313
# Single_HC in Subcallosal Cortex (right) p values is:0.003979323869882312
# Single_HC in Paracingulate Gyrus (left) are significant differences
# Single_HC in Paracingulate Gyrus (left) T values is:-2.041752100025323
# Single_HC in Paracingulate Gyrus (left) p values is:0.0411845706452757
# Single_HC in Paracingulate Gyrus (right) are significant differences
# Single_HC in Paracingulate Gyrus (right) T values is:-2.798222745654529
# Single_HC in Paracingulate Gyrus (right) p values is:0.00514163556940328
# Single_HC in Cingulate Gyrus, posterior division (left) are significant differences
# Single_HC in Cingulate Gyrus, posterior division (left) T values is:-2.6093859888885538
# Single_HC in Cingulate Gyrus, posterior division (left) p values is:0.009074841302460945
# Single_HC in Cingulate Gyrus, posterior division (right) are significant differences
# Single_HC in Cingulate Gyrus, posterior division (right) T values is:-2.3655071714319793
# Single_HC in Cingulate Gyrus, posterior division (right) p values is:0.01801151036382187
# Single_HC in Precuneous Cortex (right) are significant differences
# Single_HC in Precuneous Cortex (right) T values is:-3.4816013873770495
# Single_HC in Precuneous Cortex (right) p values is:0.0004991107211996804
# Single_HC in Cuneal Cortex (right) are significant differences
# Single_HC in Cuneal Cortex (right) T values is:-2.037090574510533
# Single_HC in Cuneal Cortex (right) p values is:0.041649438960932206
# Single_HC in Frontal Orbital Cortex (left) are significant differences
# Single_HC in Frontal Orbital Cortex (left) T values is:-4.7348757418400345
# Single_HC in Frontal Orbital Cortex (left) p values is:2.201569931914449e-06
# Single_HC in Frontal Orbital Cortex (right) are significant differences
# Single_HC in Frontal Orbital Cortex (right) T values is:-3.209694320423421
# Single_HC in Frontal Orbital Cortex (right) p values is:0.0013301140301298364
# Single_HC in Parahippocampal Gyrus, anterior division (left) are significant differences
# Single_HC in Parahippocampal Gyrus, anterior division (left) T values is:-3.638912381783548
# Single_HC in Parahippocampal Gyrus, anterior division (left) p values is:0.0002742362418194366
# Single_HC in Parahippocampal Gyrus, anterior division (right) are significant differences
# Single_HC in Parahippocampal Gyrus, anterior division (right) T values is:-4.0621953512230835
# Single_HC in Parahippocampal Gyrus, anterior division (right) p values is:4.873284949047374e-05
# Single_HC in Parahippocampal Gyrus, posterior division (left) are significant differences
# Single_HC in Parahippocampal Gyrus, posterior division (left) T values is:-2.363226282660453
# Single_HC in Parahippocampal Gyrus, posterior division (left) p values is:0.01812273687808319
# Single_HC in Lingual Gyrus (left) are significant differences
# Single_HC in Lingual Gyrus (left) T values is:-2.016222600764501
# Single_HC in Lingual Gyrus (left) p values is:0.043785308594447625
# Single_HC in Lingual Gyrus (right) are significant differences
# Single_HC in Lingual Gyrus (right) T values is:-3.562348657609355
# Single_HC in Lingual Gyrus (right) p values is:0.00036810262464381793
# Single_HC in Temporal Fusiform Cortex, anterior division (left) are significant differences
# Single_HC in Temporal Fusiform Cortex, anterior division (left) T values is:-5.000546355520311
# Single_HC in Temporal Fusiform Cortex, anterior division (left) p values is:5.747960220015003e-07
# Single_HC in Temporal Fusiform Cortex, anterior division (right) are significant differences
# Single_HC in Temporal Fusiform Cortex, anterior division (right) T values is:-3.783814349669056
# Single_HC in Temporal Fusiform Cortex, anterior division (right) p values is:0.00015473328496773409
# Single_HC in Temporal Fusiform Cortex, posterior division (left) are significant differences
# Single_HC in Temporal Fusiform Cortex, posterior division (left) T values is:-2.756265039702465
# Single_HC in Temporal Fusiform Cortex, posterior division (left) p values is:0.005849975020062459
# Single_HC in Temporal Fusiform Cortex, posterior division (right) are significant differences
# Single_HC in Temporal Fusiform Cortex, posterior division (right) T values is:-4.006804931493434
# Single_HC in Temporal Fusiform Cortex, posterior division (right) p values is:6.168924471394721e-05
# Single_HC in Temporal Occipital Fusiform Cortex (left) are significant differences
# Single_HC in Temporal Occipital Fusiform Cortex (left) T values is:-2.4531934665738118
# Single_HC in Temporal Occipital Fusiform Cortex (left) p values is:0.0141648798177344
# Single_HC in Occipital Fusiform Gyrus (left) are significant differences
# Single_HC in Occipital Fusiform Gyrus (left) T values is:-2.8559193909942935
# Single_HC in Occipital Fusiform Gyrus (left) p values is:0.0042940900239358815
# Single_HC in Occipital Fusiform Gyrus (right) are significant differences
# Single_HC in Occipital Fusiform Gyrus (right) T values is:-3.732399950321053
# Single_HC in Occipital Fusiform Gyrus (right) p values is:0.00019000258522106073
# Single_HC in Frontal Operculum Cortex (left) are significant differences
# Single_HC in Frontal Operculum Cortex (left) T values is:-3.631437781683904
# Single_HC in Frontal Operculum Cortex (left) p values is:0.0002823004875133206
# Single_HC in Frontal Operculum Cortex (right) are significant differences
# Single_HC in Frontal Operculum Cortex (right) T values is:-3.083803613778008
# Single_HC in Frontal Operculum Cortex (right) p values is:0.0020455195938658965
# Single_HC in Central Opercular Cortex (left) are significant differences
# Single_HC in Central Opercular Cortex (left) T values is:-2.7321022228425744
# Single_HC in Central Opercular Cortex (left) p values is:0.0062967224401754285
# Single_HC in Central Opercular Cortex (right) are significant differences
# Single_HC in Central Opercular Cortex (right) T values is:-2.216628710007535
# Single_HC in Central Opercular Cortex (right) p values is:0.026655700555873296
# Single_HC in Planum Polare (right) are significant differences
# Single_HC in Planum Polare (right) T values is:-2.7587466539850785
# Single_HC in Planum Polare (right) p values is:0.005805749986510955
# Single_HC in Heschl's Gyrus (includes H1 and H2) (left) are significant differences
# Single_HC in Heschl's Gyrus (includes H1 and H2) (left) T values is:-2.8948302993325354
# Single_HC in Heschl's Gyrus (includes H1 and H2) (left) p values is:0.0037962812053924377
# Single_HC in Heschl's Gyrus (includes H1 and H2) (right) are significant differences
# Single_HC in Heschl's Gyrus (includes H1 and H2) (right) T values is:-2.886059802156636
# Single_HC in Heschl's Gyrus (includes H1 and H2) (right) p values is:0.0039036709302417982
# Single_HC in Planum Temporale (left) are significant differences
# Single_HC in Planum Temporale (left) T values is:-2.4444027597514437
# Single_HC in Planum Temporale (left) p values is:0.014514747184408483
# Single_HC in Planum Temporale (right) are significant differences
# Single_HC in Planum Temporale (right) T values is:-2.153269231787538
# Single_HC in Planum Temporale (right) p values is:0.031305210180674115
# Single_HC in Occipital Pole (right) are significant differences
# Single_HC in Occipital Pole (right) T values is:-2.565946963704507
# Single_HC in Occipital Pole (right) p values is:0.010294109648119276
# Single_HC in Caudate (left) are significant differences
# Single_HC in Caudate (left) T values is:5.845625094717772
# Single_HC in Caudate (left) p values is:5.097158806144364e-09
# Single_HC in Caudate (right) are significant differences
# Single_HC in Caudate (right) T values is:5.58526319558676
# Single_HC in Caudate (right) p values is:2.3529970305524728e-08
# Single_HC in Putamen (left) are significant differences
# Single_HC in Putamen (left) T values is:2.9407892632025323
# Single_HC in Putamen (left) p values is:0.003276189292811593
# Single_HC in Pallidum (right) are significant differences
# Single_HC in Pallidum (right) T values is:2.4624307404486965
# Single_HC in Pallidum (right) p values is:0.013805278071502114
# Single_HC in Hippocampus (left) are significant differences
# Single_HC in Hippocampus (left) T values is:-4.611256943972102
# Single_HC in Hippocampus (left) p values is:4.018375368675109e-06
# Single_HC in Hippocampus (right) are significant differences
# Single_HC in Hippocampus (right) T values is:-3.4867768821673364
# Single_HC in Hippocampus (right) p values is:0.0004895553042382206
# Single_HC in Amygdala (left) are significant differences
# Single_HC in Amygdala (left) T values is:-4.082797106129817
# Single_HC in Amygdala (left) p values is:4.460835322905865e-05
# Single_HC in Amygdala (right) are significant differences
# Single_HC in Amygdala (right) T values is:-4.777001978835053
# Single_HC in Amygdala (right) p values is:1.787407615694292e-06
# Single_HC in Ventral Striatum (left) are significant differences
# Single_HC in Ventral Striatum (left) T values is:-2.137971471995939
# Single_HC in Ventral Striatum (left) p values is:0.03252685160078039
# Single_HC in Ventral Striatum (right) are significant differences
# Single_HC in Ventral Striatum (right) T values is:-2.5266102119089595
# Single_HC in Ventral Striatum (right) p values is:0.011521855900861189
# Single_HC in VI Cerebellum (left) are significant differences
# Single_HC in VI Cerebellum (left) T values is:-3.241225932753941
# Single_HC in VI Cerebellum (left) p values is:0.0011914236698084002
# Single_HC in VI Cerebellum (right) are significant differences
# Single_HC in VI Cerebellum (right) T values is:-2.666456848808456
# Single_HC in VI Cerebellum (right) p values is:0.00766952031599466
# Single_HC in Crus I Cerebellum (left) are significant differences
# Single_HC in Crus I Cerebellum (left) T values is:-2.9181705121312826
# Single_HC in Crus I Cerebellum (left) p values is:0.003523445649403323
# Single_HC in Crus I Cerebellum (right) are significant differences
# Single_HC in Crus I Cerebellum (right) T values is:-3.111725828747987
# Single_HC in Crus I Cerebellum (right) p values is:0.001861660094482409
# Single_HC in Crus II Cerebellum (left) are significant differences
# Single_HC in Crus II Cerebellum (left) T values is:-5.295104823159877
# Single_HC in Crus II Cerebellum (left) p values is:1.1975721214696478e-07
# Single_HC in Crus II Cerebellum (vermis) are significant differences
# Single_HC in Crus II Cerebellum (vermis) T values is:-2.355898852992268
# Single_HC in Crus II Cerebellum (vermis) p values is:0.018484136093275483
# Single_HC in Crus II Cerebellum (right) are significant differences
# Single_HC in Crus II Cerebellum (right) T values is:-5.293048228932449
# Single_HC in Crus II Cerebellum (right) p values is:1.2111115454960242e-07
# Single_HC in VIIb Cerebellum (left) are significant differences
# Single_HC in VIIb Cerebellum (left) T values is:-5.471875141961939
# Single_HC in VIIb Cerebellum (left) p values is:4.4873965210356914e-08
# Single_HC in VIIb Cerebellum (right) are significant differences
# Single_HC in VIIb Cerebellum (right) T values is:-5.394591256574316
# Single_HC in VIIb Cerebellum (right) p values is:6.918188499849265e-08
# Single_HC in VIIIa Cerebellum (left) are significant differences
# Single_HC in VIIIa Cerebellum (left) T values is:-5.631353741298908
# Single_HC in VIIIa Cerebellum (left) p values is:1.8034588600279733e-08
# Single_HC in VIIIa Cerebellum (vermis) are significant differences
# Single_HC in VIIIa Cerebellum (vermis) T values is:-2.935267329322098
# Single_HC in VIIIa Cerebellum (vermis) p values is:0.0033350485978504985
# Single_HC in VIIIa Cerebellum (right) are significant differences
# Single_HC in VIIIa Cerebellum (right) T values is:-5.859742287789099
# Single_HC in VIIIa Cerebellum (right) p values is:4.682655374566025e-09
# Single_HC in VIIIb Cerebellum (left) are significant differences
# Single_HC in VIIIb Cerebellum (left) T values is:-4.84406704254785
# Single_HC in VIIIb Cerebellum (left) p values is:1.2782110416775794e-06
# Single_HC in VIIIb Cerebellum (vermis) are significant differences
# Single_HC in VIIIb Cerebellum (vermis) T values is:-3.4257469037266715
# Single_HC in VIIIb Cerebellum (vermis) p values is:0.0006139055376556124
# Single_HC in VIIIb Cerebellum (right) are significant differences
# Single_HC in VIIIb Cerebellum (right) T values is:-4.627848430658095
# Single_HC in VIIIb Cerebellum (right) p values is:3.709781613570051e-06
# Single_HC in IX Cerebellum (left) are significant differences
# Single_HC in IX Cerebellum (left) T values is:-3.0843193331359773
# Single_HC in IX Cerebellum (left) p values is:0.0020419778415406986
# Single_HC in IX Cerebellum (right) are significant differences
# Single_HC in IX Cerebellum (right) T values is:-3.9492220456640545
# Single_HC in IX Cerebellum (right) p values is:7.857876824679533e-05
# Single_HC in X Cerebellum (left) are significant differences
# Single_HC in X Cerebellum (left) T values is:-3.9076744862966684
# Single_HC in X Cerebellum (left) p values is:9.338649411005928e-05
# Single_HC in X Cerebellum (vermis) are significant differences
# Single_HC in X Cerebellum (vermis) T values is:-2.157377259895207
# Single_HC in X Cerebellum (vermis) p values is:0.03098393710491354
# Single_HC in X Cerebellum (right) are significant differences
# Single_HC in X Cerebellum (right) T values is:-2.357388240376714
# Single_HC in X Cerebellum (right) p values is:0.01841017080979568

# %%
set1 = set(significant_columns_1_2)
set2 = set(significant_columns_1_3)
set3 = set(significant_columns_2_3)

intersection = set1.intersection(set2,set3)
significant2_2 = list(intersection)
len(significant2_2)
# Out:
# 68

# %% [markdown]
# #### Significantly strongest region of the three groups

# %%
set1 = set(top_10_1_2)
set2 = set(top_10_1_3)
set3 = set(top_10_2_3)

intersection = set1.intersection(set2,set3)

result_list = list(intersection)

print(len(result_list))

significant_data1 = data1[result_list]
significant_data2 = data2[result_list]
significant_data3 = data3[result_list]

combined_data = pd.concat([significant_data1.assign(Group='Group 1'),
                           significant_data2.assign(Group='Group 2'),
                           significant_data3.assign(Group='Group 3')])

new_df = pd.DataFrame(columns=['value', 'name', 'Group'])

df = combined_data

for col in df.columns[:-1]:
    name = col
    data = pd.DataFrame({'value': df[col], 'name': name, 'Group': df['Group']})
    new_df = pd.concat([new_df, data], ignore_index=True)
# Out:
# 10

# %%
import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['font.family'] = 'Times New Roman'

legend_labels = [mpatches.Patch(color='#274259', label='Severe co-morbidity'),
                 mpatches.Patch(color='#A3B2BF', label='Mild co-morbidity'),
                 mpatches.Patch(color='#D9AF62', label='HC')]

flierprops = dict(marker='o', markersize=3, markerfacecolor='grey', linestyle='none', alpha=0.6)

plt.figure(figsize=(5, 3))
sns.boxplot(x='name', y='value', data=new_df, hue='Group', 
            palette={'Group 1':'#274259', 'Group 2':'#A3B2BF','Group 3':'#D9AF62'}, width=0.8,
            flierprops=flierprops)
plt.xticks(rotation=30, ha='right')
plt.xlabel("")
plt.ylabel("GMV", fontsize=10)

plt.legend(handles=legend_labels)
#plt.savefig("D:/python_code/cluster/picture/GMV 3 Cluster.jpeg", dpi=500, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Two or two significant regions in three groups

# %%
set1 = set(top_10_1_2)
set2 = set(top_10_1_3)
set3 = set(top_10_2_3)

ten_list = sorted_column_names[:10]
print(len(ten_list))
ten_F = set(ten_list)
intersection = set2.intersection(ten_F)
result_list = list(intersection)
#result_list = sorted(result_list, key=lambda x: x[0])

print(len(result_list))
# Out:
# 10
# 8

# %%
set1 = set(significant_columns_1_2)
set2 = set(significant_columns_1_3)
set3 = set(significant_columns_2_3)

intersection = set1.intersection(set2,set3)

ten_list = sorted_column_names[:10]
set_F = set(ten_list)
intersection = intersection.intersection(set_F)
result_list = list(intersection)
result_list = sorted(result_list, key=lambda x: x[0])

print(result_list)

new_columns = ['AL', 'AR', 'IX Cb (R)', 'VI Cb (L)','VIIb Cb (L)',
               'VIIIb Cb (R)','VIIIa Cb (L)', 'VIIIa Cb (R)', 'VIIb Cb (R)', 'VIIIb Cb (L)']

significant_data1 = data1[result_list]
significant_data2 = data2[result_list]
significant_data3 = data3[result_list]

significant_data1.columns = new_columns
significant_data2.columns = new_columns
significant_data3.columns = new_columns

combined_data = pd.concat([significant_data1.assign(Group='Group 1'),
                           significant_data2.assign(Group='Group 2'),
                           significant_data3.assign(Group='Group 3')])

new_df = pd.DataFrame(columns=['value', 'name', 'Group'])

df = combined_data

for col in df.columns[:-1]:
    name = col
    data = pd.DataFrame({'value': df[col], 'name': name, 'Group': df['Group']})
    new_df = pd.concat([new_df, data], ignore_index=True)
# Out:
# ['Amygdala (left)', 'Amygdala (right)', 'IX Cerebellum (right)', 'VI Cerebellum (left)', 'VIIb Cerebellum (left)', 'VIIIb Cerebellum (right)', 'VIIIa Cerebellum (left)', 'VIIIa Cerebellum (right)', 'VIIb Cerebellum (right)', 'VIIIb Cerebellum (left)']

# %%
import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import FontProperties

mpl.rcParams['font.family'] = 'Times New Roman'

legend_labels = [mpatches.Patch(color='#E9002D', label='comorbidity'),
                 mpatches.Patch(color='#FFAA00', label='non-cormobidity'),
                 mpatches.Patch(color='#00B000', label='HC')]

flierprops = dict(marker='o', markersize=3, markerfacecolor='grey', linestyle='none', alpha=0.6)

plt.figure(figsize=(8, 4))
sns.boxplot(x='name', y='value', data=new_df, hue='Group', 
            palette={'Group 1': '#E9002D', 'Group 2': '#FFAA00','Group 3': '#00B000'}, width=0.8,
            flierprops=flierprops)
plt.xticks(rotation=20, ha='right', fontsize=10, fontweight='bold')
plt.xlabel("")
plt.ylabel("GMV", fontsize=10,  fontweight='bold')

font = FontProperties()
font.set_weight('bold')

plt.legend(handles=legend_labels, prop=font)
plt.savefig("GMV 3 Cluster.jpeg", dpi=1000, bbox_inches='tight')
plt.show()
